# %% [markdown]
# Take N export files from SPINIT for a run, identify the run type: spin-echo, FID etc. and then plot the desired data.

# %%
#ALWAYS RUN THIS CELL FIRST
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# Section 1: FID
