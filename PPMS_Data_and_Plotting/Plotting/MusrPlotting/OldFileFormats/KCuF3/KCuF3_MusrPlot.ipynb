# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import LogFormatterSciNotation

df = pd.read_csv('datafile_parsed.csv')
print(df['L1_0343'])
print(df['dataB'])

'''
# Constants
A = 1  # You can change this
B = 1  # You can change this

# x range, starting from a small positive number to avoid division by zero
x = np.linspace(0.01, 3, 1000)

# Functions
y1 = A * x**(-0.5)  # y = A * x^(-1/2)
y2 = B * x**(-1/3)  # y = B * x^(-1/3)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, y1, label=r'$y = A x^{-1/2}$', color='blue')
plt.plot(x, y2, label=r'$y = B x^{-1/3}$', color='red')
plt.title('Plots of $y = Ax^{-1/2}$ and $y = Bx^{-1/3}$')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.ylim(0, max(np.max(y1), np.max(y2)) * 1.1)  # Adjust y-limits
plt.xlim(0, 500)
'''

def gauss_to_tesla(x):
    return x/10000
#df['dataB'] = df['dataB'].apply(gauss_to_tesla)

# Plot dataT vs YBO_L2 for all runs
#plt.scatter(df['dataB'], df['L1_0343'])
plt.errorbar(df['dataB'], df['L1_0343'], yerr=df['L1_0343_err'], fmt="o")
plt.xscale('log')
plt.xlabel('Field (G)')
plt.ylabel('lambda')

plt.gca().xaxis.set_major_formatter(LogFormatterSciNotation())
#plt.ylim(-0.1,0.5)
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# 0    0.01750
# 1    0.00246
# 2    0.00054
# Name: L1_0343, dtype: float64
# 0     3000.0
# 1    10000.0
# 2    15000.0
# Name: dataB, dtype: float64

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency_'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_Lambda_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_Lambda')
plt.errorbar(df['dataT'], df['YBO_Lambda_'], yerr=df['YBO_Lambda__err'], fmt="o")

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_sigma_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_sigma_')
plt.errorbar(df['dataT'], df['YBO_sigma_'], yerr=df['YBO_sigma__err'], fmt="o")
#print(df['YBO_sigma__err'])

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_L2'], marker = 's', c='r', label = 'YBO_L2')
plt.errorbar(df['dataT'], df['YBO_L2'], yerr=df['YBO_L2_err'], marker = 'x', c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_B2'], marker = 's', c='b', label = 'YBO_B2')
plt.errorbar(df['dataT'], df['YBO_B2'], yerr=df['YBO_B2_err'], marker = 'o', c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions
#YBO_paraBet2_,YBO_paraBet2__err,YBO_paraLam2_,YBO_paraLam2__err

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_paraLam2_'], marker = 's', c='r', label = 'YBO_paraLam2_')
plt.errorbar(df['dataT'], df['YBO_paraLam2_'], yerr=df['YBO_paraLam2__err'], c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_paraBet2_'], marker = 's', c='b', label = 'YBO_paraBet2_')
plt.errorbar(df['dataT'], df['YBO_paraBet2_'], yerr=df['YBO_paraBet2__err'], c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
#[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
#[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda'], marker = 'x', c='r', label = 'Tail_Lambda')
plt.errorbar(df['dataT'], df['Tail_Lambda'], yerr=df['Tail_Lambda_err'], marker = 'o', c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta'], marker = 'o', c='b', label = 'Tail_Beta')
plt.errorbar(df['dataT'], df['Tail_Beta'], yerr=df['Tail_Beta_err'], marker = 'o', c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
[plt.axhline(y=i, color='b') for i in [0.5,1]]
[plt.axhline(y=i, color='r') for i in [2,5]]
#plt.ylim(0,19)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Tail_Beta_,Tail_Beta__err,Tail_Lambda_,Tail_Lambda__err,
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda_'], marker = 'x', c='r', label = 'Tail_Lambda_')
plt.errorbar(df['dataT'], df['Tail_Lambda_'], yerr=df['Tail_Lambda__err'], c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta_'], c='b', label = 'Tail_Beta_')
plt.errorbar(df['dataT'], df['Tail_Beta_'], yerr=df['Tail_Beta__err'], c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
#[plt.axhline(y=i, color='b') for i in [0.5,1]]
#[plt.axhline(y=i, color='r') for i in [2,5]]
plt.ylim(0,30)
#plt.title('YBO Musr fit parameters')
plt.show()

# %% [markdown]
# # Below works for the new datafile which is just a whitespace deliminated txt file

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("datafile.txt", delim_whitespace=True)
print(df.columns)
print(df)


# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Order_Vfrac_'])
plt.xlabel('Temperature (K)')
plt.ylabel('Order volume fraction')
plt.errorbar(df['dataT'], df['Order_Vfrac_'], yerr=df['Order_Vfrac_PosErr'], fmt="o")
#plt.ylim(-0.1,1.1)
plt.title('YBO Musr fit parameters')
plt.show()
