# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('datafile_parsed.csv')


# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Order_Vfrac_'])
plt.xlabel('Temperature (K)')
plt.ylabel('Order volume fraction')
plt.errorbar(df['dataT'], df['Order_Vfrac_'], yerr=df['Order_Vfrac__err'], fmt="o")
plt.ylim(-0.1,1.1)
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[7], line 7
#       5 import matplotlib.pyplot as plt
#       6 import pandas as pd
# ----> 7 df = pd.read_csv('datafile_parsed.csv')
#      10 # Plot dataT vs YBO_L2 for all runs
#      11 plt.scatter(df['dataT'], df['Order_Vfrac_'])
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:581, in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       5 import matplotlib.pyplot as plt
#       6 import numpy as np
# ----> 8 df = pd.read_csv('datafile_parsed.csv')
#      10 # Plot dataT vs YBO_L2 for all runs
#      11 plt.scatter(df['dataT'], df['Frequency'])
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\ProgramData\miniconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'datafile_parsed.csv'

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency_'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_Lambda_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_Lambda')
plt.errorbar(df['dataT'], df['YBO_Lambda_'], yerr=df['YBO_Lambda__err'], fmt="o")

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YBO_Lambda_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 10
#       7 df = pd.read_csv('datafile_parsed.csv')
#       9 # Plot dataT vs YBO_L2 for all runs
# ---> 10 plt.scatter(df['dataT'], df['YBO_Lambda_'])
#      11 plt.xlabel('Temperature (K)')
#      12 plt.ylabel('YBO_Lambda')
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'YBO_Lambda_'

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_sigma_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_sigma_')
plt.errorbar(df['dataT'], df['YBO_sigma_'], yerr=df['YBO_sigma__err'], fmt="o")
#print(df['YBO_sigma__err'])

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_L2'], marker = 's', c='r', label = 'YBO_L2')
plt.errorbar(df['dataT'], df['YBO_L2'], yerr=df['YBO_L2_err'], marker = 'x', c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_B2'], marker = 's', c='b', label = 'YBO_B2')
plt.errorbar(df['dataT'], df['YBO_B2'], yerr=df['YBO_B2_err'], marker = 'o', c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YBO_L2_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 10
#       7 df = pd.read_csv('datafile_parsed.csv')
#       9 # Plot dataT vs YBO_L2 for all runs
# ---> 10 plt.scatter(df['dataT'], df['YBO_L2_'], marker = 's', c='r', label = 'YBO_L2')
#      11 plt.errorbar(df['dataT'], df['YBO_L2_'], yerr=df['YBO_L2__err'], marker = 'x', c='r', fmt="o")
#      13 plt.scatter(df['dataT'], df['YBO_B2_'], marker = 's', c='b', label = 'YBO_B2')
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'YBO_L2_'

# %%
#Plotting section using defined functions
#YBO_paraBet2_,YBO_paraBet2__err,YBO_paraLam2_,YBO_paraLam2__err

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_paraLam2_'], marker = 's', c='r', label = 'YBO_paraLam2_')
plt.errorbar(df['dataT'], df['YBO_paraLam2_'], yerr=df['YBO_paraLam2__err'], c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_paraBet2_'], marker = 's', c='b', label = 'YBO_paraBet2_')
plt.errorbar(df['dataT'], df['YBO_paraBet2_'], yerr=df['YBO_paraBet2__err'], c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
#[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
#[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda'], marker = 'x', c='r', label = 'Tail_Lambda')
plt.errorbar(df['dataT'], df['Tail_Lambda'], yerr=df['Tail_Lambda_err'], marker = 'o', c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta'], marker = 'o', c='b', label = 'Tail_Beta')
plt.errorbar(df['dataT'], df['Tail_Beta'], yerr=df['Tail_Beta_err'], marker = 'o', c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
[plt.axhline(y=i, color='b') for i in [0.5,1]]
[plt.axhline(y=i, color='r') for i in [2,5]]
#plt.ylim(0,19)
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Tail_Lambda'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 10
#       7 df = pd.read_csv('datafile_parsed.csv')
#       9 # Plot dataT vs YBO_L2 for all runs
# ---> 10 plt.scatter(df['dataT'], df['Tail_Lambda'], marker = 'x', c='r', label = 'Tail_Lambda')
#      11 plt.errorbar(df['dataT'], df['Tail_Lambda'], yerr=df['Tail_Lambda_err'], marker = 'o', c='r',fmt="o")
#      13 plt.scatter(df['dataT'], df['Tail_Beta'], marker = 'o', c='b', label = 'Tail_Beta')
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Tail_Lambda'

# %%
#Tail_Beta_,Tail_Beta__err,Tail_Lambda_,Tail_Lambda__err,
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('datafile_parsed.csv')

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda_'], marker = 'x', c='r', label = 'Tail_Lambda_')
plt.errorbar(df['dataT'], df['Tail_Lambda_'], yerr=df['Tail_Lambda__err'], c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta_'], c='b', label = 'Tail_Beta_')
plt.errorbar(df['dataT'], df['Tail_Beta_'], yerr=df['Tail_Beta__err'], c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
#[plt.axhline(y=i, color='b') for i in [0.5,1]]
#[plt.axhline(y=i, color='r') for i in [2,5]]
plt.ylim(0,30)
#plt.title('YBO Musr fit parameters')
plt.show()

# %% [markdown]
# # Below works for the new datafile which is just a whitespace deliminated txt file

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv("datafile.txt", delim_whitespace=True)
print(df.columns)
print(df)


# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Order_Vfrac_'])
plt.xlabel('Temperature (K)')
plt.ylabel('Order volume fraction')
plt.errorbar(df['dataT'], df['Order_Vfrac_'], yerr=df['Order_Vfrac_PosErr'], fmt="o")
#plt.ylim(-0.1,1.1)
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_30396\1177162084.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv("datafile.txt", delim_whitespace=True)
# Index(['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Ag_Lambda',
#        'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr',
#        'Ag_BetaNegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Tail',
#        'TailPosErr', 'TailNegErr', 'YBO_Lambda_', 'YBO_Lambda_PosErr',
#        'YBO_Lambda_NegErr', 'Frequency_', 'Frequency_PosErr',
#        'Frequency_NegErr', 'Order_Vfrac_', 'Order_Vfrac_PosErr',
#        'Order_Vfrac_NegErr', 'YBO_L2_', 'YBO_L2_PosErr', 'YBO_L2_NegErr',
#        'Tail_Lambda_', 'Tail_Lambda_PosErr', 'Tail_Lambda_NegErr',
#        'Tail_Beta_', 'Tail_Beta_PosErr', 'Tail_Beta_NegErr', 'CHISQ', 'NDF',
#        'CHISQred', 'RUN'],
#       dtype='object')
#       dataT  dataTErr  dataB  dataSpinRot  Ag_Lambda  Ag_LambdaPosErr  \
# 0   0.03330   0.00020      0         6.45     0.0389           0.0043
# 1   0.10002   0.00008      0         6.45     0.0389           0.0043
# 2   0.15000   0.00004      0         6.45     0.0389           0.0043
# 3   0.20000   0.00005      0         6.45     0.0389           0.0043
# 4   0.25000   0.00007      0         6.45     0.0389           0.0043
# 5   0.30000   0.00010      0         6.45     0.0389           0.0043
# 6   0.35000   0.00010      0         6.45     0.0389           0.0043
# 7   0.40010   0.00020      0         6.45     0.0389           0.0043
# 8   0.49999   0.00009      0         6.45     0.0389           0.0043
# 9   0.60000   0.00010      0         6.45     0.0389           0.0043
# 10  0.69990   0.00020      0         6.45     0.0389           0.0043
# 11  0.80000   0.00030      0         6.45     0.0389           0.0043
# 12  1.99999   0.00008      0         6.45     0.0389           0.0043
#
#     Ag_LambdaNegErr  Ag_Beta  Ag_BetaPosErr  Ag_BetaNegErr  ...  Tail_Lambda_  \
# 0            0.0043        1              0              0  ...           5.0
# 1            0.0043        1              0              0  ...           NaN
# 2            0.0043        1              0              0  ...           NaN
# 3            0.0043        1              0              0  ...           NaN
# 4            0.0043        1              0              0  ...           NaN
# 5            0.0043        1              0              0  ...           NaN
# 6            0.0043        1              0              0  ...           NaN
# 7            0.0043        1              0              0  ...           NaN
# 8            0.0043        1              0              0  ...           NaN
# 9            0.0043        1              0              0  ...           NaN
# 10           0.0043        1              0              0  ...           NaN
# 11           0.0043        1              0              0  ...           NaN
# 12           0.0043        1              0              0  ...           NaN
#
#     Tail_Lambda_PosErr  Tail_Lambda_NegErr  Tail_Beta_  Tail_Beta_PosErr  \
# 0                  2.1                 2.1         0.5             0.012
# 1                  NaN                 NaN         NaN               NaN
# 2                  NaN                 NaN         NaN               NaN
# 3                  NaN                 NaN         NaN               NaN
# 4                  NaN                 NaN         NaN               NaN
# 5                  NaN                 NaN         NaN               NaN
# 6                  NaN                 NaN         NaN               NaN
# 7                  NaN                 NaN         NaN               NaN
# 8                  NaN                 NaN         NaN               NaN
# 9                  NaN                 NaN         NaN               NaN
# 10                 NaN                 NaN         NaN               NaN
# 11                 NaN                 NaN         NaN               NaN
# 12                 NaN                 NaN         NaN               NaN
#
#     Tail_Beta_NegErr   CHISQ     NDF  CHISQred     RUN
# 0              0.012  8137.8  8214.0  0.990723  2460.0
# 1                NaN     NaN     NaN       NaN     NaN
# 2                NaN     NaN     NaN       NaN     NaN
# 3                NaN     NaN     NaN       NaN     NaN
# 4                NaN     NaN     NaN       NaN     NaN
# 5                NaN     NaN     NaN       NaN     NaN
# 6                NaN     NaN     NaN       NaN     NaN
# 7                NaN     NaN     NaN       NaN     NaN
# 8                NaN     NaN     NaN       NaN     NaN
# 9                NaN     NaN     NaN       NaN     NaN
# 10               NaN     NaN     NaN       NaN     NaN
# 11               NaN     NaN     NaN       NaN     NaN
# 12               NaN     NaN     NaN       NaN     NaN
#
# [13 rows x 38 columns]
