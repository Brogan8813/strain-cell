# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os


datafile = '22-07-25_full_with_NegativeBkg_freeParaBeta.txt'

#datafile = 'beta1_July_08_002.txt'
#'22-07-25_full_with_bkg.txt'

df = pd.read_csv(datafile, delim_whitespace=True)
list(df)
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\1157627159.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# ['dataT',
#  'dataTErr',
#  'dataB',
#  'dataSpinRot',
#  'Alpha',
#  'AlphaPosErr',
#  'AlphaNegErr',
#  'Asy_tot',
#  'Asy_totPosErr',
#  'Asy_totNegErr',
#  'Ag_frac',
#  'Ag_fracPosErr',
#  'Ag_fracNegErr',
#  'Ag_Lambda',
#  'Ag_LambdaPosErr',
#  'Ag_LambdaNegErr',
#  'YBO_sigma_2461',
#  'YBO_sigma_2461PosErr',
#  'YBO_sigma_2461NegErr',
#  'Phase',
#  'PhasePosErr',
#  'PhaseNegErr',
#  'Frequency_2461',
#  'Frequency_2461PosErr',
#  'Frequency_2461NegErr',
#  'Order_Vfrac_2461',
#  'Order_Vfrac_2461PosErr',
#  'Order_Vfrac_2461NegErr',
#  'YBO_paraLam2_2461',
#  'YBO_paraLam2_2461PosErr',
#  'YBO_paraLam2_2461NegErr',
#  'Tail',
#  'TailPosErr',
#  'TailNegErr',
#  'Tail_Lambda_2461',
#  'Tail_Lambda_2461PosErr',
#  'Tail_Lambda_2461NegErr',
#  'YBO_paraBeta2_2461',
#  'YBO_paraBeta2_2461PosErr',
#  'YBO_paraBeta2_2461NegErr',
#  'constant',
#  'constantPosErr',
#  'constantNegErr',
#  'CHISQ',
#  'NDF',
#  'CHISQred',
#  'RUN']

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('Phase')
plt.errorbar(df['dataT'], df['Phase'], yerr=df['PhasePosErr'],fmt="d", color='red', alpha=.8)
#plt.xlim((0,0.52))
print(df['dataT'])
#plt.ylim((0, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')

#save plot
title=f'phase'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)


plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\3423352321.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0     0.03330
# 1     0.10002
# 2     0.15000
# 3     0.20000
# 4     0.25000
# 5     0.30000
# 6     0.35000
# 7     0.40010
# 8     0.49999
# 9     0.60000
# 10    0.69990
# 11    0.80000
# 12    1.99999
# Name: dataT, dtype: float64

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('$λ_{Ag}$')
plt.errorbar(df['dataT'], df['Ag_Lambda'], yerr=df['Ag_LambdaPosErr'],fmt="d", color='orange', alpha=.8)
#plt.xlim((0,0.5))
#plt.ylim((15, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')

#save plot
title=f'lambda_Ag'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

average = df['Ag_Lambda'].mean()
print("Average Ag_Lambda:", average)
#excluding final value
average_excl_last = df['Ag_Lambda'].iloc[:-2].mean()
print("Average excluding last two values:", average_excl_last)


plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\3624873736.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Average Ag_Lambda: 0.024230769230769236
# Average excluding last two values: 0.02481818181818182

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)

try:
    plt.xlabel('Temperature (K)')
    plt.ylabel('Background (fraction of total Asymmetry)') 
    plt.errorbar(df['dataT'], df['constant'], yerr=df['constantPosErr'],fmt="d", color='forestgreen', alpha=.8) 
    #plt.xlim((0,0.6))
    #plt.ylim((0, 8.2))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')  
    plt.grid('both')
    plt.legend()
#plt.title('YBO Musr fit parameters')   

    #save plot
    title=f'lambda_tail'
    # Make sure the folder exists
    output_dir = f'{datafile} parameter_plots'
    os.makedirs(output_dir, exist_ok=True)
    # Save with a sanitized filename
    plot_filename = title.lower().replace(" ", "_") + ".png"
    plot_filepath = os.path.join(output_dir, plot_filename)
    plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)
    plt.show()
except:
    print('no constant background in this dataset')
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\540501920.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
'''
#Remove this section as it has the lambdas plotted on one axis instead of 2

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load data
df = pd.read_csv(datafile, delim_whitespace=True)

# Create mask for each condition
mask_tail = df['dataT'] <= 0.51
mask_para = df['dataT'] >= 0.49


# Begin plotting
#plt.figure(figsize=(8, 6))
plt.xlabel('Temperature (K)')
plt.ylabel('$λ$')
plt.grid('both')

# Plot Tail_Lambda for T <= 0.5 K
plt.errorbar(
    df['dataT'][mask_tail],
    df['Tail_Lambda_2461'][mask_tail],
    yerr=df['Tail_Lambda_2461PosErr'][mask_tail],
    fmt="d", color='forestgreen',
    alpha=0.8, label='$λ_{tail}$ (T ≤ 0.5 K)'
)

# Plot YBO_paraLam2 for T >= 0.5 K
plt.errorbar(
    df['dataT'][mask_para],
    df['YBO_paraLam2_2461'][mask_para],
    yerr=df['YBO_paraLam2_2461PosErr'][mask_para],
    fmt="d", color='salmon',
    alpha=0.8, label='$λ_{para}$ (T ≥ 0.5 K)'
)

#plt.xlim((0, 2))
#plt.ylim((0, 20))
plt.legend()
plt.tight_layout()

# Save the figure
title = 'lambda_tail_and_para_split'
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)
plt.show()

'''
# Out:
# '\n#Remove this section as it has the lambdas plotted on one axis instead of 2\n\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\nimport os\n\n# Load data\ndf = pd.read_csv(datafile, delim_whitespace=True)\n\n# Create mask for each condition\nmask_tail = df[\'dataT\'] <= 0.51\nmask_para = df[\'dataT\'] >= 0.49\n\n\n# Begin plotting\n#plt.figure(figsize=(8, 6))\nplt.xlabel(\'Temperature (K)\')\nplt.ylabel(\'$λ$\')\nplt.grid(\'both\')\n\n# Plot Tail_Lambda for T <= 0.5 K\nplt.errorbar(\n    df[\'dataT\'][mask_tail],\n    df[\'Tail_Lambda_2461\'][mask_tail],\n    yerr=df[\'Tail_Lambda_2461PosErr\'][mask_tail],\n    fmt="d", color=\'forestgreen\',\n    alpha=0.8, label=\'$λ_{tail}$ (T ≤ 0.5 K)\'\n)\n\n# Plot YBO_paraLam2 for T >= 0.5 K\nplt.errorbar(\n    df[\'dataT\'][mask_para],\n    df[\'YBO_paraLam2_2461\'][mask_para],\n    yerr=df[\'YBO_paraLam2_2461PosErr\'][mask_para],\n    fmt="d", color=\'salmon\',\n    alpha=0.8, label=\'$λ_{para}$ (T ≥ 0.5 K)\'\n)\n\n#plt.xlim((0, 2))\n#plt.ylim((0, 20))\nplt.legend()\nplt.tight_layout()\n\n# Save the figure\ntitle = \'lambda_tail_and_para_split\'\noutput_dir = f\'{datafile} parameter_plots\'\nos.makedirs(output_dir, exist_ok=True)\nplot_filename = title.lower().replace(" ", "_") + ".png"\nplot_filepath = os.path.join(output_dir, plot_filename)\nplt.savefig(plot_filepath, bbox_inches=\'tight\', dpi=300)\nplt.show()\n\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load the data
df = pd.read_csv(datafile, delim_whitespace=True)

# Create masks
mask_tail = df['dataT'] <= 0.51
mask_para = df['dataT'] >= 0.49

# Mask
df_tail = df[mask_tail][['dataT', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr']]
df_para = df[mask_para][['dataT', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr']]

# Create figure and axes with default size
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()  # Right y-axis

# Plot λ_tail (left axis)
p1 = ax1.errorbar(
    df_tail['dataT'],
    df_tail['Tail_Lambda_2461'],
    yerr=df_tail['Tail_Lambda_2461PosErr'],
    fmt='d', color='forestgreen',
    alpha=0.8, label='$λ_{tail}$ (T ≤ 0.5 K)'
)

# Plot λ_para (right axis)
p2 = ax2.errorbar(
    df_para['dataT'],
    df_para['YBO_paraLam2_2461'],
    yerr=df_para['YBO_paraLam2_2461PosErr'],
    fmt='o', color='mediumblue',
    alpha=0.8, label='$λ_{para}$ (T ≥ 0.5 K)'
)

# Axis labels
ax1.set_xlabel('Temperature (K)', fontsize=14)
ax1.set_ylabel('$λ_{tail}$', fontsize=14, color='forestgreen')
ax2.set_ylabel('$λ_{para}$', fontsize=14, color='mediumblue')

# Axis limits
#ax1.set_xlim(0, 0.6)
ax1.set_ylim(0, 10.2)
ax2.set_ylim(0, 10.2)

# Grid and layout
ax1.grid(True, which='both')
fig.tight_layout()

# Combine legends into one
lines = [p1[0], p2[0]]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper right', fontsize=12)

# Save plot
title = 'lambda_tail_and_para_dual_axis'
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

# Show plot
plt.show()

print(df['Tail_Lambda_2461'][mask_tail])
print(df['YBO_paraLam2_2461'][mask_para])
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\886806502.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\886806502.py:56: MatplotlibDeprecationWarning: An artist whose label starts with an underscore was passed to legend(); such artists will no longer be ignored in the future.  To suppress this warning, explicitly filter out such artists, e.g. with `[art for art in artists if not art.get_label().startswith('_')]`.
#   ax1.legend(lines, labels, loc='upper right', fontsize=12)
# 0    0.476
# 1    0.548
# 2    0.514
# 3    0.569
# 4    0.603
# 5    0.700
# 6    0.880
# 7    1.300
# 8    0.300
# Name: Tail_Lambda_2461, dtype: float64
# 8     2.47
# 9     1.82
# 10    1.47
# 11    1.69
# 12    1.54
# Name: YBO_paraLam2_2461, dtype: float64

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('σ')
plt.errorbar(df['dataT'], df['YBO_sigma_2461'], yerr=df['YBO_sigma_2461PosErr'], fmt="d", color='peru', alpha=.8)
#plt.xlim((0,0.5))
#plt.ylim((10, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')

#save plot
title=f'sigma'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\1256498239.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('$λ_{para}$')
plt.errorbar(df['dataT'], df['YBO_paraLam2_2461'], yerr=df['YBO_paraLam2_2461PosErr'], fmt="d", color='salmon', alpha=.8)
plt.xlim((0,2.1))
#plt.ylim((0, 3))

#plt.axhline(2.317,color = 'r')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')
#save plot
title=f'lambda_para'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\1255048767.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)
try:

    plt.xlabel('Temperature (K)')
    plt.ylabel('$β_{para}$')
    plt.errorbar(df['dataT'], df['YBO_paraBeta2_2461'], yerr=df['YBO_paraBeta2_2461PosErr'], fmt="d", color='salmon', alpha=.8)
    plt.xlim((0,2.1))
    #plt.ylim((0, 3))

    #plt.axhline(2.317,color = 'r')
    plt.grid('both')
    plt.legend()
    #plt.title('YBO Musr fit parameters')
    #save plot
    title=f'beta_para'
    # Make sure the folder exists
    output_dir = f'{datafile} parameter_plots'
    os.makedirs(output_dir, exist_ok=True)
    # Save with a sanitized filename
    plot_filename = title.lower().replace(" ", "_") + ".png"
    plot_filepath = os.path.join(output_dir, plot_filename)
    plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

    plt.show()
    
except:
    print('No Paramagnetic beta in this dataset, continue')
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\2722790546.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('Field(G)')
plt.errorbar(df['dataT'], df['Frequency_2461'], yerr=df['Frequency_2461PosErr'], fmt="d", color='lightsteelblue', alpha=.8)
plt.xlim((0,2))
plt.ylim((0, 700))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')
#save plot
title=f'field'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\1387748463.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#
df = pd.read_csv(datafile, delim_whitespace=True)

#print(df)
#Asy_tot_PosErr
# Plot dataT vs YBO_L2 for all runs
#plt.scatter(df['dataT'], df['Order_Vfrac_2461'])
plt.xlabel('Temperature (K)')
plt.ylabel('Ordered Volume fraction')
plt.errorbar(df['dataT'], df['Order_Vfrac_2461'], yerr=df['Order_Vfrac_2461PosErr'], fmt="d", color='plum')
plt.ylim(0,1.15)
plt.grid('both')
#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.legend()
#plt.title('YBO Musr fit parameters')
#save plot
title=f'OVF'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\3572767178.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from PIL import Image
import os
import math

output_dir = f'{datafile} parameter_plots'

# Get all .png files in the folder (sorted by filename)
plot_filenames = sorted([
    os.path.join(output_dir, f)
    for f in os.listdir(output_dir)
    if f.endswith(".png")
])

# Load images
images = [Image.open(f) for f in plot_filenames]

# Limit to first 9 images (if more)
images = images[:9]

# Grid size
cols = 3
rows = math.ceil(len(images) / cols)

# Resize all to same dimensions (based on max width/height)
max_width = max(img.width for img in images)
max_height = max(img.height for img in images)

# Create blank canvas
combined_width = cols * max_width
combined_height = rows * max_height
combined = Image.new("RGB", (combined_width, combined_height), color=(255, 255, 255))

# Paste images in grid
for index, img in enumerate(images):
    row = index // cols
    col = index % cols
    # Pad image to max size if needed
    padded = Image.new("RGB", (max_width, max_height), (255, 255, 255))
    padded.paste(img, ((max_width - img.width) // 2, (max_height - img.height) // 2))
    combined.paste(padded, (col * max_width, row * max_height))

# Save final combined image
combined_path = os.path.join(output_dir, "combined_plot_grid.png")
combined.save(combined_path)

# %% [markdown]
# Plotting the function and components of it below

# %%
import numpy as np

def muon_asymmetry(
    t,
    f_F,             # ordered volume fraction
    sigma,             # sigma of YBO ordered gaussian
    nu,              # frequency ν
    phi,             # phase φ in degrees
    lam_tail,        # λ_tail
    lam_para,        # λ_paramagnetic
    lam_Ag,# λ_Ag       
    Background=0,
    beta_tail=1,       # β_tail
    beta_para=1,          # β_2
    beta_Ag=1,
    A_T=0.2392,
    Ag_F=0.5
    ):
    # Convert phase to radians
    phi_rad = np.pi * phi / 180
    
    #convert field back to frequency
    mu_gyro = 0.0135538817
    nu = nu*mu_gyro
    print(nu)

    # Ordered YBO component 
    term1 = f_F * (2/3) * np.exp(-0.5 * (sigma * t)**2) * np.cos(2 * np.pi * nu * t + phi_rad)
    
    # Ordered Tail exponential decay
    term2 = f_F * (1/3) * np.exp(-(lam_tail * t)**beta_tail)
    
    # Disordered YBO paramagnetic component
    term3 = (1 - f_F) * np.exp(-(lam_para * t)**beta_para)
    
    # Silver (Ag) component
    term4 = np.exp(-(lam_Ag * t)**beta_Ag)
    
    # Full asymmetry function
    A = A_T * (1 - Ag_F) * (term1 + term2 + term3) + A_T * Ag_F * term4 + A_T * Background

    return A

# %%
times = np.linspace(0,10, 10000)


y=muon_asymmetry(times, 
                f_F=0.8369,
                sigma=28.5,
                nu=501.1,
                phi=21.5,
                lam_tail=15.3,
                lam_para=1, 
                lam_Ag=0.038 )

plt.xlabel('Time (μs)')
plt.ylabel('Asymmetry')

t=np.array(times)
f_F=0.8369
sigma=28.5
nu=501.1
phi=21.5
lam_tail=15.3
lam_para=1 
lam_Ag=0.038          # λ_Ag     
beta_tail=1       # β_ta   
beta_para=1         # β_2
beta_Ag=1
A_T=0.2392
Ag_F=0.5 
Background=0
# Convert phase to radians
print(phi)
phi_rad = np.pi * phi / 180

    
#convert field back to frequency
mu_gyro = 0.0135538817
nu = nu*mu_gyro


    # Ordered YBO component 
term1 = f_F * (2/3) * np.exp(-0.5 * (sigma * t)**2) * np.cos(2 * np.pi * nu * t + phi_rad)
    
    # Ordered Tail exponential decay
term2 = f_F * (1/3) * np.exp(-(lam_tail * t)**beta_tail)
    
    # Disordered YBO paramagnetic component
term3 = (1 - f_F) * np.exp(-(lam_para * t)**beta_para)
    
    # Silver (Ag) component
term4 = np.exp(-(lam_Ag * t)**beta_Ag)
    
    # Full asymmetry function
A = A_T * (1 - Ag_F) * (term1 + term2 + term3) + A_T * Ag_F * term4

A1= A_T * (1 - Ag_F) * (term1) #K-T gaussian damped cosine
A2= A_T * (1 - Ag_F) * (term2) #Ordered Tail term
A3= A_T * (1 - Ag_F) * (term3) #Disordered paramagnetic
A4= A_T * Ag_F * term4 #Silver component
A5=A1+A2+A3+A4

plt.plot(times, A1, label='K-T gaussian damped cosine', color='r')
plt.plot(times, A2, label='Ordered Tail term', color='gold')
plt.plot(times, A3, label='Disordered paramagnetic', color='green')
plt.plot(times, A4, label='Silver component', color='silver')

plt.plot(times, A5, label='CheckTheyAdd', color='magenta')


#plt.ylim(0,0.25)
#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.xlim(0,1)
plt.title('YBO Musr fit parameters')
plt.plot(times, A, label='Full Asymmetry', color='b')
plt.legend()
plt.show()
# Out:
# 6.79185011987
# 21.5

# %%
#code to take musrfit output file and plot the desired run's different components
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


#beta_fixed_post_lock_25_009.txt
def Plot_YBO_fit_components(run_no, datafile,x_min=0,x_max=1,points=10000):
    '''
    run_no: the run number from the msr file you want to plot.
    datafile: the datafile where the fit parameters are stored. This must be in the same subfolder, or use the full filepath, ensure it is a headered file exported from musrfit.
    x_min/x_max: limits in time domain (μs) of where you want to plot until
    points: number of points for the function to be plotted at, effective resolution 
    '''
    df = pd.read_csv(datafile, delim_whitespace=True)
    print(f'headers are: {list(df)}')

    df_run = df[df['RUN']==run_no].squeeze() #to make a series not a dataframe so I can do maths on it easily when multiplying by times which is an array. squeeze makes these from series of length (1,) into scalars so there is no broadcasting errors.

    times = np.linspace(x_min,x_max, points)
    t=np.array(times)

    f_F=df_run['Order_Vfrac_2461']
    sigma=df_run['YBO_sigma_2461']
    nu=df_run['Frequency_2461']
    phi=df_run['Phase']
    lam_tail=df_run['Tail_Lambda_2461']
    lam_para=df_run['YBO_paraLam2_2461'] 
    lam_Ag=df_run['Ag_Lambda']          # λ_Ag     
    beta_tail=df_run['Tail_Beta_2461']       # β_ta   
    beta_para=df_run['YBO_paraBet2_2461']        # β_2
    beta_Ag=df_run['Ag_Beta']
    A_T=df_run['Asy_tot']
    Ag_F=df_run['Ag_frac']
    Temp=df_run['dataT']
    
    A=muon_asymmetry(t, f_F,sigma,nu,phi,lam_tail,lam_para,lam_Ag,beta_tail,beta_para,beta_Ag,A_T,Ag_F)

    phi_rad = np.pi * phi / 180

    
    #convert field back to frequency
    mu_gyro = 0.0135538817
    nu = nu*mu_gyro


    # Ordered YBO component 
    term1 = f_F * (2/3) * np.exp(-0.5 * (sigma * t)**2) * np.cos(2 * np.pi * nu * t + phi_rad)
    
    # Ordered Tail exponential decay
    term2 = f_F * (1/3) * np.exp(-(lam_tail * t)**beta_tail)
    
    # Disordered YBO paramagnetic component
    term3 = (1 - f_F) * np.exp(-(lam_para * t)**beta_para)
    
    # Silver (Ag) component
    term4 = np.exp(-(lam_Ag * t)**beta_Ag)
    
    # Full asymmetry function
    #A = A_T * (1 - Ag_F) * (term1 + term2 + term3) + A_T * Ag_F * term4

    A1= A_T * (1 - Ag_F) * (term1) #K-T gaussian damped cosine
    A2= A_T * (1 - Ag_F) * (term2) #Ordered Tail term
    A3= A_T * (1 - Ag_F) * (term3) #Disordered paramagnetic
    A4= A_T * Ag_F * term4 #Silver component
    A5=A1+A2+A3+A4

    plt.plot(times, A1, label='K-T gaussian damped cosine', color='r')
    plt.plot(times, A2, label='Ordered Tail term', color='gold')
    plt.plot(times, A3, label='Disordered paramagnetic', color='green')
    plt.plot(times, A4, label='Silver component', color='silver')

    plt.plot(times, A5, label='CheckTheyAdd', color='magenta')


    #plt.ylim(0,0.25)
    #plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
    plt.xlim(0,1)
    plt.title(f'YBO Musr fit parameters for run {run_no}, {Temp} K')
    plt.plot(times, A, label='Full Asymmetry', color='b')
    plt.legend()
    plt.show()

#Plot_YBO_fit_components(2460, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2465, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2466, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2467, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2468, 'beta_fixed_post_lock_25_009.txt')
Plot_YBO_fit_components(2460, 'beta1_July_08_002.txt')
Plot_YBO_fit_components(2467, 'beta1_July_08_002.txt')
Plot_YBO_fit_components(2468, 'beta1_July_08_002.txt')
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 5.871541552439999
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 0.25887914047
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 0.33071471348

# %%
Plot_YBO_fit_components(2460, 'beta_fixed_post_lock_26_015.txt')
Plot_YBO_fit_components(2465, 'beta_fixed_post_lock_26_015.txt')
Plot_YBO_fit_components(2466, 'beta_fixed_post_lock_26_015.txt')
Plot_YBO_fit_components(2467, 'beta_fixed_post_lock_26_015.txt')
Plot_YBO_fit_components(2468, 'beta_fixed_post_lock_26_015.txt')
Plot_YBO_fit_components(2472, 'beta_fixed_post_lock_26_015.txt')
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 5.925757079239999
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 5.68720876132
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 3.9075840941099997
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 2.25943207939
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 0.35104553602999994
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\585755534.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# headers are: ['dataT', 'dataTErr', 'dataB', 'dataSpinRot', 'Alpha', 'AlphaPosErr', 'AlphaNegErr', 'Asy_tot', 'Asy_totPosErr', 'Asy_totNegErr', 'sigma', 'sigmaPosErr', 'sigmaNegErr', 'Ag_frac', 'Ag_fracPosErr', 'Ag_fracNegErr', 'Ag_Lambda', 'Ag_LambdaPosErr', 'Ag_LambdaNegErr', 'Ag_Beta', 'Ag_BetaPosErr', 'Ag_BetaNegErr', 'YBO_sigma_2461', 'YBO_sigma_2461PosErr', 'YBO_sigma_2461NegErr', 'YBO_Beta', 'YBO_BetaPosErr', 'YBO_BetaNegErr', 'Phase', 'PhasePosErr', 'PhaseNegErr', 'Frequency_2461', 'Frequency_2461PosErr', 'Frequency_2461NegErr', 'Order_Vfrac_2461', 'Order_Vfrac_2461PosErr', 'Order_Vfrac_2461NegErr', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr', 'YBO_paraLam2_2461NegErr', 'YBO_paraBet2_2461', 'YBO_paraBet2_2461PosErr', 'YBO_paraBet2_2461NegErr', 'Tail', 'TailPosErr', 'TailNegErr', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr', 'Tail_Lambda_2461NegErr', 'Tail_Beta_2461', 'Tail_Beta_2461PosErr', 'Tail_Beta_2461NegErr', 'CHISQ', 'NDF', 'CHISQred', 'RUN']
# 2.18759650638

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency_'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_61344\611861638.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\TXB909\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frequency_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 11
#       8 df = pd.read_csv(datafile, delim_whitespace=True)
#      10 # Plot dataT vs YBO_L2 for all runs
# ---> 11 plt.scatter(df['dataT'], df['Frequency_'])
#      12 #plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
#      13 plt.xlabel('Temperature (K)')
#
# File c:\Users\TXB909\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\TXB909\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Frequency_'

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency_'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_39904\611861638.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\TXB909\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frequency_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 11
#       8 df = pd.read_csv(datafile, delim_whitespace=True)
#      10 # Plot dataT vs YBO_L2 for all runs
# ---> 11 plt.scatter(df['dataT'], df['Frequency_'])
#      12 #plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
#      13 plt.xlabel('Temperature (K)')
#
# File c:\Users\TXB909\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\TXB909\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Frequency_'

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_Lambda_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_Lambda')
plt.errorbar(df['dataT'], df['YBO_Lambda_'], yerr=df['YBO_Lambda__err'], fmt="o")

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_sigma_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_sigma_')
plt.errorbar(df['dataT'], df['YBO_sigma_'], yerr=df['YBO_sigma__err'], fmt="o")
#print(df['YBO_sigma__err'])

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_L2'], marker = 's', c='r', label = 'YBO_L2')
plt.errorbar(df['dataT'], df['YBO_L2'], yerr=df['YBO_L2_err'], marker = 'x', c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_B2'], marker = 's', c='b', label = 'YBO_B2')
plt.errorbar(df['dataT'], df['YBO_B2'], yerr=df['YBO_B2_err'], marker = 'o', c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions
#YBO_paraBet2_,YBO_paraBet2__err,YBO_paraLam2_,YBO_paraLam2__err

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_paraLam2_'], marker = 's', c='r', label = 'YBO_paraLam2_')
plt.errorbar(df['dataT'], df['YBO_paraLam2_'], yerr=df['YBO_paraLam2__err'], c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_paraBet2_'], marker = 's', c='b', label = 'YBO_paraBet2_')
plt.errorbar(df['dataT'], df['YBO_paraBet2_'], yerr=df['YBO_paraBet2__err'], c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
#[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
#[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda'], marker = 'x', c='r', label = 'Tail_Lambda')
plt.errorbar(df['dataT'], df['Tail_Lambda'], yerr=df['Tail_Lambda_err'], marker = 'o', c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta'], marker = 'o', c='b', label = 'Tail_Beta')
plt.errorbar(df['dataT'], df['Tail_Beta'], yerr=df['Tail_Beta_err'], marker = 'o', c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
[plt.axhline(y=i, color='b') for i in [0.5,1]]
[plt.axhline(y=i, color='r') for i in [2,5]]
#plt.ylim(0,19)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Tail_Beta_,Tail_Beta__err,Tail_Lambda_,Tail_Lambda__err,
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda_'], marker = 'x', c='r', label = 'Tail_Lambda_')
plt.errorbar(df['dataT'], df['Tail_Lambda_'], yerr=df['Tail_Lambda__err'], c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta_'], c='b', label = 'Tail_Beta_')
plt.errorbar(df['dataT'], df['Tail_Beta_'], yerr=df['Tail_Beta__err'], c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
#[plt.axhline(y=i, color='b') for i in [0.5,1]]
#[plt.axhline(y=i, color='r') for i in [2,5]]
plt.ylim(0,30)
#plt.title('YBO Musr fit parameters')
plt.show()
