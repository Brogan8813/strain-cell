# %%
import pandas as pd
import matplotlib.pyplot as plt


datafile = 'beta_fixed_post_lock_24_004.txt'
df = pd.read_csv(datafile, delim_whitespace=True)
list(df)
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\771531850.py:6: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# ['dataT',
#  'dataTErr',
#  'dataB',
#  'dataSpinRot',
#  'Alpha',
#  'AlphaPosErr',
#  'AlphaNegErr',
#  'Asy_tot',
#  'Asy_totPosErr',
#  'Asy_totNegErr',
#  'sigma',
#  'sigmaPosErr',
#  'sigmaNegErr',
#  'Ag_frac',
#  'Ag_fracPosErr',
#  'Ag_fracNegErr',
#  'Ag_Lambda',
#  'Ag_LambdaPosErr',
#  'Ag_LambdaNegErr',
#  'Ag_Beta',
#  'Ag_BetaPosErr',
#  'Ag_BetaNegErr',
#  'YBO_sigma_2461',
#  'YBO_sigma_2461PosErr',
#  'YBO_sigma_2461NegErr',
#  'YBO_Beta',
#  'YBO_BetaPosErr',
#  'YBO_BetaNegErr',
#  'Phase',
#  'PhasePosErr',
#  'PhaseNegErr',
#  'Frequency_2461',
#  'Frequency_2461PosErr',
#  'Frequency_2461NegErr',
#  'Order_Vfrac_2461',
#  'Order_Vfrac_2461PosErr',
#  'Order_Vfrac_2461NegErr',
#  'YBO_paraLam2_2461',
#  'YBO_paraLam2_2461PosErr',
#  'YBO_paraLam2_2461NegErr',
#  'YBO_paraBet2_2461',
#  'YBO_paraBet2_2461PosErr',
#  'YBO_paraBet2_2461NegErr',
#  'Tail',
#  'TailPosErr',
#  'TailNegErr',
#  'Tail_Lambda_2461',
#  'Tail_Lambda_2461PosErr',
#  'Tail_Lambda_2461NegErr',
#  'Tail_Beta_2461',
#  'Tail_Beta_2461PosErr',
#  'Tail_Beta_2461NegErr',
#  'CHISQ',
#  'NDF',
#  'CHISQred',
#  'RUN']

# %%
#Plotting section using defined functions

df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('Ag_Lambda')
plt.errorbar(df['dataT'], df['Ag_Lambda'], yerr=df['Ag_LambdaPosErr'],fmt="d", color='orange', alpha=.8)
#plt.xlim((0,0.5))
#plt.ylim((15, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')

plt.legend()
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\4109965879.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\4109965879.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions

df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('Tail_Lambda')
plt.errorbar(df['dataT'], df['Tail_Lambda_2461'], yerr=df['Tail_Lambda_2461PosErr'],fmt="d", color='forestgreen', alpha=.8)
#plt.xlim((0,0.5))
#plt.ylim((15, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')

plt.legend()
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\3733630471.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\3733630471.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions

df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('YBO_sigma')
plt.errorbar(df['dataT'], df['YBO_sigma_2461'], yerr=df['YBO_sigma_2461PosErr'], fmt="d", color='peru', alpha=.8)
plt.xlim((0,0.5))
plt.ylim((15, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')

plt.legend()
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\2585168103.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\2585168103.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions

df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('YBO_paraLam2')
plt.errorbar(df['dataT'], df['YBO_paraLam2_2461'], yerr=df['YBO_paraLam2_2461PosErr'], fmt="d", color='salmon', alpha=.8)
plt.xlim((0.36,2.1))
#plt.ylim((15, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')

plt.legend()
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\604178544.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\604178544.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions

df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('Field(G)')
plt.errorbar(df['dataT'], df['Frequency_2461'], yerr=df['Frequency_2461PosErr'], fmt="d", color='lightsteelblue', alpha=.8)
plt.xlim((0,0.5))
plt.ylim((0, 600))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')

plt.legend()
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\974954877.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\974954877.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions

df = pd.read_csv(datafile, delim_whitespace=True)

#print(df)
#Asy_tot_PosErr
# Plot dataT vs YBO_L2 for all runs
#plt.scatter(df['dataT'], df['Order_Vfrac_2461'])
plt.xlabel('Temperature (K)')
plt.ylabel('Ordered Volume fraction')
plt.errorbar(df['dataT'], df['Order_Vfrac_2461'], yerr=df['Order_Vfrac_2461PosErr'], fmt="d", color='plum')
#plt.ylim(0,0.25)
#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.legend()
plt.title('YBO Musr fit parameters')
plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\3969816912.py:3: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\3969816912.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency_'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()
# Out:
# C:\Users\thoma\AppData\Local\Temp\ipykernel_19732\611861638.py:8: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frequency_'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 11
#       8 df = pd.read_csv(datafile, delim_whitespace=True)
#      10 # Plot dataT vs YBO_L2 for all runs
# ---> 11 plt.scatter(df['dataT'], df['Frequency_'])
#      12 #plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
#      13 plt.xlabel('Temperature (K)')
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\thoma\Documents\Physics_Work\Python Scripts\strain-cell\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Frequency_'

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Frequency_'])
#plt.errorbar(df['dataT'], df['Frequency_'], yerr=df['Frequency_err'], fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('Field (Oe)')
plt.xlim(0,0.55)
plt.ylim(0,600)
plt.title('YBO Musr fit parameters')

xs=np.linspace(0,0.8)
ys = -((np.exp(xs+0.90))**(4.6)-600)
plt.plot(xs,ys)

plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_Lambda_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_Lambda')
plt.errorbar(df['dataT'], df['YBO_Lambda_'], yerr=df['YBO_Lambda__err'], fmt="o")

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_sigma_'])
plt.xlabel('Temperature (K)')
plt.ylabel('YBO_sigma_')
plt.errorbar(df['dataT'], df['YBO_sigma_'], yerr=df['YBO_sigma__err'], fmt="o")
#print(df['YBO_sigma__err'])

plt.xlim(0,0.5)
plt.ylim(0,40)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_L2'], marker = 's', c='r', label = 'YBO_L2')
plt.errorbar(df['dataT'], df['YBO_L2'], yerr=df['YBO_L2_err'], marker = 'x', c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_B2'], marker = 's', c='b', label = 'YBO_B2')
plt.errorbar(df['dataT'], df['YBO_B2'], yerr=df['YBO_B2_err'], marker = 'o', c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions
#YBO_paraBet2_,YBO_paraBet2__err,YBO_paraLam2_,YBO_paraLam2__err

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['YBO_paraLam2_'], marker = 's', c='r', label = 'YBO_paraLam2_')
plt.errorbar(df['dataT'], df['YBO_paraLam2_'], yerr=df['YBO_paraLam2__err'], c='r', fmt="o")

plt.scatter(df['dataT'], df['YBO_paraBet2_'], marker = 's', c='b', label = 'YBO_paraBet2_')
plt.errorbar(df['dataT'], df['YBO_paraBet2_'], yerr=df['YBO_paraBet2__err'], c='b',fmt="o")
plt.xlabel('Temperature (K)')
plt.ylabel('y')
#[plt.axhline(y=i, color='b') for i in [0.4,0.9]]
#[plt.axhline(y=i, color='r') for i in [1,3]]

#plt.hlines(0.4,0.9,c='b')
#plt.hlines(1,3,c='r')
plt.legend()
plt.xlim(0.4, 2.3)
plt.ylim(-0.3,3.5)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda'], marker = 'x', c='r', label = 'Tail_Lambda')
plt.errorbar(df['dataT'], df['Tail_Lambda'], yerr=df['Tail_Lambda_err'], marker = 'o', c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta'], marker = 'o', c='b', label = 'Tail_Beta')
plt.errorbar(df['dataT'], df['Tail_Beta'], yerr=df['Tail_Beta_err'], marker = 'o', c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
[plt.axhline(y=i, color='b') for i in [0.5,1]]
[plt.axhline(y=i, color='r') for i in [2,5]]
#plt.ylim(0,19)
plt.title('YBO Musr fit parameters')
plt.show()

# %%
#Tail_Beta_,Tail_Beta__err,Tail_Lambda_,Tail_Lambda__err,
#Plotting section using defined functions


import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(datafile, delim_whitespace=True)

# Plot dataT vs YBO_L2 for all runs
plt.scatter(df['dataT'], df['Tail_Lambda_'], marker = 'x', c='r', label = 'Tail_Lambda_')
plt.errorbar(df['dataT'], df['Tail_Lambda_'], yerr=df['Tail_Lambda__err'], c='r',fmt="o")

plt.scatter(df['dataT'], df['Tail_Beta_'], c='b', label = 'Tail_Beta_')
plt.errorbar(df['dataT'], df['Tail_Beta_'], yerr=df['Tail_Beta__err'], c='b',fmt="o")

plt.xlabel('Temperature (K)')
plt.ylabel('y')
#plt.axhline(0.9)
plt.legend()
plt.xlim(0,0.5)
#[plt.axhline(y=i, color='b') for i in [0.5,1]]
#[plt.axhline(y=i, color='r') for i in [2,5]]
plt.ylim(0,30)
#plt.title('YBO Musr fit parameters')
plt.show()
