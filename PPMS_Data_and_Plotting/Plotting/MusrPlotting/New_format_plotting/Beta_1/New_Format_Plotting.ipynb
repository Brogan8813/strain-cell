# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import matplotlib.font_manager as fm

#datafile = 'A_23-07-25_negativeBkg_Beta0p8_sigma.txt'
datafile = 'B_23-07-25_full_with_NegativeBkgBeta_0p8.txt'

#'22-07-25_full_with_bkg.txt'

df = pd.read_csv(datafile, delim_whitespace=True)
list(df)
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\765006242.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# ['dataT',
#  'dataTErr',
#  'dataB',
#  'dataSpinRot',
#  'Alpha',
#  'AlphaPosErr',
#  'AlphaNegErr',
#  'Asy_tot',
#  'Asy_totPosErr',
#  'Asy_totNegErr',
#  'Ag_frac',
#  'Ag_fracPosErr',
#  'Ag_fracNegErr',
#  'Ag_Lambda',
#  'Ag_LambdaPosErr',
#  'Ag_LambdaNegErr',
#  'YBO_sigma_2461',
#  'YBO_sigma_2461PosErr',
#  'YBO_sigma_2461NegErr',
#  'Phase',
#  'PhasePosErr',
#  'PhaseNegErr',
#  'Frequency_2461',
#  'Frequency_2461PosErr',
#  'Frequency_2461NegErr',
#  'Order_Vfrac_2461',
#  'Order_Vfrac_2461PosErr',
#  'Order_Vfrac_2461NegErr',
#  'YBO_paraLam2_2461',
#  'YBO_paraLam2_2461PosErr',
#  'YBO_paraLam2_2461NegErr',
#  'Tail',
#  'TailPosErr',
#  'TailNegErr',
#  'Tail_Lambda_2461',
#  'Tail_Lambda_2461PosErr',
# ...

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)

font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
plt.ylabel('Phase',fontsize=14, weight='bold')

plt.errorbar(df['dataT'], df['Phase'], yerr=df['PhasePosErr'],fmt="d", color='red', alpha=.8)
#plt.xlim((0,0.52))
print(df['dataT'])
#plt.ylim((0, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')

#save plot
title=f'phase'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\1204294366.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\1204294366.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# 0     0.03220
# 1     0.15000
# 2     0.20000
# 3     0.25000
# 4     0.30000
# 5     0.35000
# 6     0.40010
# 7     0.45020
# 8     0.49998
# 9     0.60000
# 10    0.79950
# 11    2.00000
# Name: dataT, dtype: float64

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


plt.xlabel('Temperature (K)')
plt.ylabel('$λ_{Ag}$')
plt.errorbar(df['dataT'], df['Ag_Lambda'], yerr=df['Ag_LambdaPosErr'],fmt="d", color='orange', alpha=.8)
#plt.xlim((0,0.5))
#plt.ylim((15, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')

#save plot
title=f'lambda_Ag'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

average = df['Ag_Lambda'].mean()
print("Average Ag_Lambda:", average)
#excluding final value
average_excl_last = df['Ag_Lambda'].iloc[:-2].mean()
print("Average excluding last two values:", average_excl_last)


plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\3624873736.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\3624873736.py:18: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Average Ag_Lambda: 0.025083333333333336
# Average excluding last two values: 0.0252

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)


font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
plt.ylabel('Background fraction of total asymmetry (%)',fontsize=14, weight='bold')
try:
    #plt.xlabel('Temperature (K)')
    #plt.ylabel('Background (fraction of total Asymmetry)') 
    plt.errorbar(df['dataT'], df['constant']*100, yerr=df['constantPosErr'],fmt="d", color='forestgreen', alpha=.8) 
    #plt.xlim((0,0.6))
    #plt.ylim((0, 8.2))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')  
    plt.grid('both')
    plt.legend()
#plt.title('YBO Musr fit parameters')   

    #save plot
    title=f'lambda_tail'
    # Make sure the folder exists
    output_dir = f'{datafile} parameter_plots'
    os.makedirs(output_dir, exist_ok=True)
    # Save with a sanitized filename
    plot_filename = title.lower().replace(" ", "_") + ".png"
    plot_filepath = os.path.join(output_dir, plot_filename)
    plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)
    plt.show()
except:
    print('no constant background in this dataset')
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\4184389438.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\4184389438.py:27: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
'''
#Remove this section as it has the lambdas plotted on one axis instead of 2

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load data
df = pd.read_csv(datafile, delim_whitespace=True)

# Create mask for each condition
mask_tail = df['dataT'] <= 0.51
mask_para = df['dataT'] >= 0.49


# Begin plotting
#plt.figure(figsize=(8, 6))
plt.xlabel('Temperature (K)')
plt.ylabel('$λ$')
plt.grid('both')

# Plot Tail_Lambda for T <= 0.5 K
plt.errorbar(
    df['dataT'][mask_tail],
    df['Tail_Lambda_2461'][mask_tail],
    yerr=df['Tail_Lambda_2461PosErr'][mask_tail],
    fmt="d", color='forestgreen',
    alpha=0.8, label='$λ_{tail}$ (T ≤ 0.5 K)'
)

# Plot YBO_paraLam2 for T >= 0.5 K
plt.errorbar(
    df['dataT'][mask_para],
    df['YBO_paraLam2_2461'][mask_para],
    yerr=df['YBO_paraLam2_2461PosErr'][mask_para],
    fmt="d", color='salmon',
    alpha=0.8, label='$λ_{para}$ (T ≥ 0.5 K)'
)

#plt.xlim((0, 2))
#plt.ylim((0, 20))
plt.legend()
plt.tight_layout()

# Save the figure
title = 'lambda_tail_and_para_split'
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)
plt.show()

'''
# Out:
# '\n#Remove this section as it has the lambdas plotted on one axis instead of 2\n\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport numpy as np\nimport os\n\n# Load data\ndf = pd.read_csv(datafile, delim_whitespace=True)\n\n# Create mask for each condition\nmask_tail = df[\'dataT\'] <= 0.51\nmask_para = df[\'dataT\'] >= 0.49\n\n\n# Begin plotting\n#plt.figure(figsize=(8, 6))\nplt.xlabel(\'Temperature (K)\')\nplt.ylabel(\'$λ$\')\nplt.grid(\'both\')\n\n# Plot Tail_Lambda for T <= 0.5 K\nplt.errorbar(\n    df[\'dataT\'][mask_tail],\n    df[\'Tail_Lambda_2461\'][mask_tail],\n    yerr=df[\'Tail_Lambda_2461PosErr\'][mask_tail],\n    fmt="d", color=\'forestgreen\',\n    alpha=0.8, label=\'$λ_{tail}$ (T ≤ 0.5 K)\'\n)\n\n# Plot YBO_paraLam2 for T >= 0.5 K\nplt.errorbar(\n    df[\'dataT\'][mask_para],\n    df[\'YBO_paraLam2_2461\'][mask_para],\n    yerr=df[\'YBO_paraLam2_2461PosErr\'][mask_para],\n    fmt="d", color=\'salmon\',\n    alpha=0.8, label=\'$λ_{para}$ (T ≥ 0.5 K)\'\n)\n\n
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# Load the data


datafileA = 'A_23-07-25_negativeBkg_Beta0p8_sigma.txt'
datafileB = 'B_23-07-25_full_with_NegativeBkgBeta_0p8.txt'


dfA = pd.read_csv(datafileA, delim_whitespace=True)
dfB = pd.read_csv(datafileB, delim_whitespace=True)


df = pd.read_csv(datafile, delim_whitespace=True)

# Create masks
mask_tail = df['dataT'] <= 0.49
mask_para = df['dataT'] >= 0.49
mask_tailA = dfA['dataT'] <= 0.49
mask_paraA = dfA['dataT'] >= 0.49
mask_tailB = dfB['dataT'] <= 0.49
mask_paraB = dfB['dataT'] >= 0.49

# Mask
df_tail = df[mask_tail][['dataT', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr']]
df_para = df[mask_para][['dataT', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr']]

# Mask
dfA_tail = dfA[mask_tailA][['dataT', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr']]
dfA_para = dfA[mask_paraA][['dataT', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr']]

# Mask
dfB_tail = dfB[mask_tailB][['dataT', 'Tail_Lambda_2461', 'Tail_Lambda_2461PosErr']]
dfB_para = dfB[mask_paraB][['dataT', 'YBO_paraLam2_2461', 'YBO_paraLam2_2461PosErr']]

# Create figure and axes with default size
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()  # Right y-axis
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
# Plot λ_tail (left axis)
p1 = ax1.errorbar(
    dfA_tail['dataT'],
    dfA_tail['Tail_Lambda_2461'],
    yerr=dfA_tail['Tail_Lambda_2461PosErr'],
    fmt='d', color='forestgreen',
    alpha=0.8, label='$λ_{tail}$ (T ≤ 0.5 K) Sample A'
)
p1 = ax1.errorbar(
    dfB_tail['dataT'],
    dfB_tail['Tail_Lambda_2461'],
    yerr=dfB_tail['Tail_Lambda_2461PosErr'],
    fmt='s', color='olive',
    alpha=0.8, label='$λ_{tail}$ (T ≤ 0.5 K) Sample B'
)

# Plot λ_para (right axis)
p2 = ax2.errorbar(
    dfA_para['dataT'],
    dfA_para['YBO_paraLam2_2461'],
    yerr=dfA_para['YBO_paraLam2_2461PosErr'],
    fmt='^', color='teal',
    alpha=0.8, label='$λ_{para}$ (T ≥ 0.5 K) Sample A'
)
# Plot λ_para (right axis)
p2 = ax2.errorbar(
    dfB_para['dataT'],
    dfB_para['YBO_paraLam2_2461'],
    yerr=dfB_para['YBO_paraLam2_2461PosErr'],
    fmt='p', color='mediumblue',
    alpha=0.8, label='$λ_{para}$ (T ≥ 0.5 K) Sample B'
)

# Axis labels

font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()


ax1.set_xlabel('Temperature (K)', fontsize=14,weight='bold')

ax1.set_ylabel('$λ_{tail}$  $(\mu\mathrm{s})^{-1}$', fontsize=14, weight='bold')
ax2.set_ylabel('$λ_{para}$  $(\mu\mathrm{s})^{-1}$', fontsize=14, weight='bold')

# Axis limits
#ax1.set_xlim(0, 0.6)
ax1.set_ylim(0, 10.2)
ax2.set_ylim(0, 10.2)

# Grid and layout
ax1.grid(True, which='both')
fig.tight_layout()

# Combine legends into one
lines = [p1[0], p2[0]]
labels = [line.get_label() for line in lines]
#ax1.legend(lines, labels, loc='upper right', fontsize=12)
ax1.legend()
ax2.legend(bbox_to_anchor=(1, 0.85))
# Save plot
title = 'lambda_tail_and_para_dual_axis'
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

# Show plot
plt.show()

print(df['Tail_Lambda_2461'][mask_tail])
print(df['YBO_paraLam2_2461'][mask_para])
# Out:
# <>:86: SyntaxWarning: invalid escape sequence '\m'
# <>:87: SyntaxWarning: invalid escape sequence '\m'
# <>:86: SyntaxWarning: invalid escape sequence '\m'
# <>:87: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\3498071219.py:86: SyntaxWarning: invalid escape sequence '\m'
#   ax1.set_ylabel('$λ_{tail}$  $(\mu\mathrm{s})^{-1}$', fontsize=14, weight='bold')
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\3498071219.py:87: SyntaxWarning: invalid escape sequence '\m'
#   ax2.set_ylabel('$λ_{para}$  $(\mu\mathrm{s})^{-1}$', fontsize=14, weight='bold')
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\3498071219.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfA = pd.read_csv(datafileA, delim_whitespace=True)
# ...

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


datafileA = 'A_23-07-25_negativeBkg_Beta0p8_sigma.txt'
datafileB = 'B_23-07-25_full_with_NegativeBkgBeta_0p8.txt'


dfA = pd.read_csv(datafileA, delim_whitespace=True)
dfB = pd.read_csv(datafileB, delim_whitespace=True)



df = pd.read_csv(datafile, delim_whitespace=True)

font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
plt.ylabel('σ  $(\mu\mathrm{s})^{-1}$',fontsize=14, weight='bold')



plt.errorbar(dfA['dataT'], dfA['YBO_sigma_2461'], yerr=dfA['YBO_sigma_2461PosErr'], fmt="d", color='peru', alpha=.7,label='Sample A')
plt.errorbar(dfB['dataT'], dfB['YBO_sigma_2461'], yerr=dfB['YBO_sigma_2461PosErr'], fmt="o", color='saddlebrown', alpha=.7, label='Sample B')
plt.xlim((0,0.51))
#plt.ylim((10, 35))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')

#save plot
title=f'sigma'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename

plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\m'
# <>:25: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\2723188842.py:25: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('σ  $(\mu\mathrm{s})^{-1}$',fontsize=14, weight='bold')
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\2723188842.py:11: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfA = pd.read_csv(datafileA, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\2723188842.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfB = pd.read_csv(datafileB, delim_whitespace=True)
# ...

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)

font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
plt.ylabel('$λ_{para}$   $(\mu\mathrm{s})^{-1}$',fontsize=14, weight='bold')


plt.errorbar(df['dataT'], df['YBO_paraLam2_2461'], yerr=df['YBO_paraLam2_2461PosErr'], fmt="d", color='salmon', alpha=.8)
plt.xlim((0,2.1))
#plt.ylim((0, 3))

#plt.axhline(2.317,color = 'r')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')
#save plot
title=f'lambda_para'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# <>:16: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\2201496535.py:16: SyntaxWarning: invalid escape sequence '\m'
#   plt.ylabel('$λ_{para}$   $(\mu\mathrm{s})^{-1}$',fontsize=14, weight='bold')
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\2201496535.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\2201496535.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv(datafile, delim_whitespace=True)
try:
    font_path = 'C:\\Windows\\Fonts\\times.TTF'
    fprop = fm.FontProperties(fname=font_path)
    plt.rcParams['font.family'] = fprop.get_name()
    plt.rc('xtick', labelsize=12)
    plt.rc('ytick', labelsize=12)

    plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
    plt.ylabel('$β_{para}$',fontsize=14, weight='bold')

    plt.errorbar(dfA['dataT'], dfA['YBO_paraBeta2_2461'], yerr=dfA['YBO_paraBeta2_2461PosErr'], fmt="d", color='salmon', alpha=.7, label='Sample A')
    plt.errorbar(dfB['dataT'], dfB['YBO_paraBeta2_2461'], yerr=dfB['YBO_paraBeta2_2461PosErr'], fmt="o", color='orangered', alpha=.7, label='Sample B')
    plt.xlim((0,2.1))
    #plt.ylim((0, 3))

    #plt.axhline(2.317,color = 'r')
    plt.grid('both')
    plt.legend()
    #plt.title('YBO Musr fit parameters')
    #save plot
    title=f'beta_para'
    # Make sure the folder exists
    output_dir = f'{datafile} parameter_plots'
    os.makedirs(output_dir, exist_ok=True)
    # Save with a sanitized filename
    plot_filename = title.lower().replace(" ", "_") + ".png"
    plot_filepath = os.path.join(output_dir, plot_filename)
    plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

    plt.show()
    
except:
    print('No Paramagnetic beta in this dataset, continue')
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\3906721489.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

datafileA = 'A_23-07-25_negativeBkg_Beta0p8_sigma.txt'
datafileB = 'B_23-07-25_full_with_NegativeBkgBeta_0p8.txt'


dfA = pd.read_csv(datafileA, delim_whitespace=True)
dfB = pd.read_csv(datafileB, delim_whitespace=True)



df = pd.read_csv(datafile, delim_whitespace=True)

font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
plt.ylabel('Field (G)',fontsize=14, weight='bold')

plt.errorbar(dfA['dataT'], dfA['Frequency_2461'], yerr=dfA['Frequency_2461PosErr'], fmt="d", color='lightsteelblue', alpha=.7, label='Sample A')
plt.errorbar(dfB['dataT'], dfB['Frequency_2461'], yerr=dfB['Frequency_2461PosErr'], fmt="o", color='darkcyan', alpha=.7, label='Sample B')
plt.xlim((0,2))
plt.ylim((0, 700))

#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.grid('both')
plt.legend()
#plt.title('YBO Musr fit parameters')
#save plot
title=f'field'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\939743340.py:10: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfA = pd.read_csv(datafileA, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\939743340.py:11: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfB = pd.read_csv(datafileB, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\939743340.py:15: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)

# %%
#Plotting section using defined functions
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


datafileA = 'A_23-07-25_negativeBkg_Beta0p8_sigma.txt'
datafileB = 'B_23-07-25_full_with_NegativeBkgBeta_0p8.txt'


dfA = pd.read_csv(datafileA, delim_whitespace=True)
dfB = pd.read_csv(datafileB, delim_whitespace=True)


#
df = pd.read_csv(datafile, delim_whitespace=True)

#print(df)
#Asy_tot_PosErr
# Plot dataT vs YBO_L2 for all runs
#plt.scatter(df['dataT'], df['Order_Vfrac_2461'])

font_path = 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=font_path)
plt.rcParams['font.family'] = fprop.get_name()
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)

plt.xlabel('Temperature (K)',fontsize=14, weight='bold')
plt.ylabel('Ordered Fraction',fontsize=14, weight='bold')


plt.errorbar(dfA['dataT'], dfA['Order_Vfrac_2461'], yerr=dfA['Order_Vfrac_2461PosErr'], fmt="d",alpha=0.7, color='plum', label='Sample A')
plt.errorbar(dfB['dataT'], dfB['Order_Vfrac_2461'], yerr=dfB['Order_Vfrac_2461PosErr'], fmt="o",alpha=0.7, color='crimson', label='Sample B')
plt.ylim(0,1.1)
plt.grid('both')
#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.legend()
#plt.title('YBO Musr fit parameters')
#save plot
title=f'OVF'
# Make sure the folder exists
output_dir = f'{datafile} parameter_plots'
os.makedirs(output_dir, exist_ok=True)
# Save with a sanitized filename
plot_filename = title.lower().replace(" ", "_") + ".png"
plot_filepath = os.path.join(output_dir, plot_filename)
#plt.savefig(plot_filepath, bbox_inches='tight', dpi=300)

plt.show()
# Out:
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\298824312.py:11: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfA = pd.read_csv(datafileA, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\298824312.py:12: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   dfB = pd.read_csv(datafileB, delim_whitespace=True)
# C:\Users\TXB909\AppData\Local\Temp\ipykernel_121540\298824312.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(datafile, delim_whitespace=True)

# %%
# from PIL import Image
# import os
# import math

# output_dir = f'{datafile} parameter_plots'

# # Get all .png files in the folder (sorted by filename)
# plot_filenames = sorted([
#     os.path.join(output_dir, f)
#     for f in os.listdir(output_dir)
#     if f.endswith(".png")
# ])

# # Load images
# images = [Image.open(f) for f in plot_filenames]

# # Limit to first 9 images (if more)
# images = images[:9]

# # Grid size
# cols = 3
# rows = math.ceil(len(images) / cols)

# # Resize all to same dimensions (based on max width/height)
# max_width = max(img.width for img in images)
# max_height = max(img.height for img in images)

# # Create blank canvas
# combined_width = cols * max_width
# combined_height = rows * max_height
# combined = Image.new("RGB", (combined_width, combined_height), color=(255, 255, 255))

# # Paste images in grid
# for index, img in enumerate(images):
#     row = index // cols
#     col = index % cols
#     # Pad image to max size if needed
#     padded = Image.new("RGB", (max_width, max_height), (255, 255, 255))
#     padded.paste(img, ((max_width - img.width) // 2, (max_height - img.height) // 2))
#     combined.paste(padded, (col * max_width, row * max_height))

# # Save final combined image
# combined_path = os.path.join(output_dir, "combined_plot_grid.png")
# combined.save(combined_path)

from PIL import Image
import os
import math

# Raise PIL's decompression bomb limit (or set to None to disable entirely)
Image.MAX_IMAGE_PIXELS = None  # disable the check since these are your own trusted files

output_dir = f'{datafile}Spectra_and_fit_plots'

plot_filenames = sorted([
    os.path.join(output_dir, f)
    for f in os.listdir(output_dir)
    if f.endswith(".png") and f != "combined_plot_grid.png"  # exclude previous combined output
])

if not plot_filenames:
    raise FileNotFoundError(f"No PNG files found in {output_dir}")

# Load and resize images to a manageable size before combining
TARGET_WIDTH = 800  # pixels per panel — adjust to taste

def load_and_resize(path, target_width):
    img = Image.open(path).convert("RGB")
    ratio = target_width / img.width
    new_height = int(img.height * ratio)
    return img.resize((target_width, new_height), Image.LANCZOS)

images = [load_and_resize(f, TARGET_WIDTH) for f in plot_filenames]
images = images[:9]

cols = 3
rows = math.ceil(len(images) / cols)

max_width = max(img.width for img in images)
max_height = max(img.height for img in images)

combined = Image.new("RGB", (cols * max_width, rows * max_height), color=(255, 255, 255))

for index, img in enumerate(images):
    row = index // cols
    col = index % cols
    padded = Image.new("RGB", (max_width, max_height), (255, 255, 255))
    padded.paste(img, ((max_width - img.width) // 2, (max_height - img.height) // 2))
    combined.paste(padded, (col * max_width, row * max_height))

combined_path = os.path.join(output_dir, "combined_plot_grid.png")
combined.save(combined_path, dpi=(150, 150))
print(f"Saved combined grid to {combined_path}")
# Out:
# Saved combined grid to B_23-07-25_full_with_NegativeBkgBeta_0p8.txtSpectra_and_fit_plots\combined_plot_grid.png

# %% [markdown]
# Plotting the function and components of it below

# %%
import numpy as np

def muon_asymmetry(
    t,
    f_F,             # ordered volume fraction
    sigma,             # sigma of YBO ordered gaussian
    nu,              # frequency ν
    phi,             # phase φ in degrees
    lam_tail,        # λ_tail
    lam_para,        # λ_paramagnetic
    lam_Ag,# λ_Ag       
    Background=0,
    beta_tail=1,       # β_tail
    beta_para=1,          # β_2
    beta_Ag=1,
    A_T=0.2392,
    Ag_F=0.5
    ):
    # Convert phase to radians
    phi_rad = np.pi * phi / 180
    
    #convert field back to frequency
    mu_gyro = 0.0135538817
    nu = nu*mu_gyro
    print(nu)

    # Ordered YBO component 
    term1 = f_F * (2/3) * np.exp(-0.5 * (sigma * t)**2) * np.cos(2 * np.pi * nu * t + phi_rad)
    
    # Ordered Tail exponential decay
    term2 = f_F * (1/3) * np.exp(-(lam_tail * t)**beta_tail)
    
    # Disordered YBO paramagnetic component
    term3 = (1 - f_F) * np.exp(-(lam_para * t)**beta_para)
    
    # Silver (Ag) component
    term4 = np.exp(-(lam_Ag * t)**beta_Ag)
    
    # Full asymmetry function
    A = A_T * (1 - Ag_F) * (term1 + term2 + term3) + A_T * Ag_F * term4 + A_T * Background

    return A

# %%
times = np.linspace(0,10, 10000)


y=muon_asymmetry(times, 
                f_F=0.8369,
                sigma=28.5,
                nu=501.1,
                phi=21.5,
                lam_tail=15.3,
                lam_para=1, 
                lam_Ag=0.038 )

plt.xlabel('Time (μs)')
plt.ylabel('Asymmetry')

t=np.array(times)
f_F=0.8369
sigma=28.5
nu=501.1
phi=21.5
lam_tail=15.3
lam_para=1 
lam_Ag=0.038          # λ_Ag     
beta_tail=1       # β_ta   
beta_para=1         # β_2
beta_Ag=1
A_T=0.2392
Ag_F=0.5 
Background=0
# Convert phase to radians
print(phi)
phi_rad = np.pi * phi / 180

    
#convert field back to frequency
mu_gyro = 0.0135538817
nu = nu*mu_gyro


    # Ordered YBO component 
term1 = f_F * (2/3) * np.exp(-0.5 * (sigma * t)**2) * np.cos(2 * np.pi * nu * t + phi_rad)
    
    # Ordered Tail exponential decay
term2 = f_F * (1/3) * np.exp(-(lam_tail * t)**beta_tail)
    
    # Disordered YBO paramagnetic component
term3 = (1 - f_F) * np.exp(-(lam_para * t)**beta_para)
    
    # Silver (Ag) component
term4 = np.exp(-(lam_Ag * t)**beta_Ag)
    
    # Full asymmetry function
A = A_T * (1 - Ag_F) * (term1 + term2 + term3) + A_T * Ag_F * term4

A1= A_T * (1 - Ag_F) * (term1) #K-T gaussian damped cosine
A2= A_T * (1 - Ag_F) * (term2) #Ordered Tail term
A3= A_T * (1 - Ag_F) * (term3) #Disordered paramagnetic
A4= A_T * Ag_F * term4 #Silver component
A5=A1+A2+A3+A4

plt.plot(times, A1, label='K-T gaussian damped cosine', color='r')
plt.plot(times, A2, label='Ordered Tail term', color='gold')
plt.plot(times, A3, label='Disordered paramagnetic', color='green')
plt.plot(times, A4, label='Silver component', color='silver')

plt.plot(times, A5, label='CheckTheyAdd', color='magenta')


#plt.ylim(0,0.25)
#plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
plt.xlim(0,1)
plt.title('YBO Musr fit parameters')
plt.plot(times, A, label='Full Asymmetry', color='b')
plt.legend()
plt.show()
# Out:
# 6.79185011987
# 21.5

# %%
#code to take musrfit output file and plot the desired run's different components
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


#beta_fixed_post_lock_25_009.txt
def Plot_YBO_fit_components(run_no, datafile,x_min=0,x_max=1,points=10000):
    '''
    run_no: the run number from the msr file you want to plot.
    datafile: the datafile where the fit parameters are stored. This must be in the same subfolder, or use the full filepath, ensure it is a headered file exported from musrfit.
    x_min/x_max: limits in time domain (μs) of where you want to plot until
    points: number of points for the function to be plotted at, effective resolution 
    '''
    df = pd.read_csv(datafile, delim_whitespace=True)
    print(f'headers are: {list(df)}')

    df_run = df[df['RUN']==run_no].squeeze() #to make a series not a dataframe so I can do maths on it easily when multiplying by times which is an array. squeeze makes these from series of length (1,) into scalars so there is no broadcasting errors.

    times = np.linspace(x_min,x_max, points)
    t=np.array(times)

    f_F=df_run['Order_Vfrac_2461']
    sigma=df_run['YBO_sigma_2461']
    nu=df_run['Frequency_2461']
    phi=df_run['Phase']
    lam_tail=df_run['Tail_Lambda_2461']
    lam_para=df_run['YBO_paraLam2_2461'] 
    lam_Ag=df_run['Ag_Lambda']          # λ_Ag     
    beta_tail=df_run['Tail_Beta_2461']       # β_ta   
    beta_para=df_run['YBO_paraBet2_2461']        # β_2
    beta_Ag=df_run['Ag_Beta']
    A_T=df_run['Asy_tot']
    Ag_F=df_run['Ag_frac']
    Temp=df_run['dataT']
    
    A=muon_asymmetry(t, f_F,sigma,nu,phi,lam_tail,lam_para,lam_Ag,beta_tail,beta_para,beta_Ag,A_T,Ag_F)

    phi_rad = np.pi * phi / 180

    
    #convert field back to frequency
    mu_gyro = 0.0135538817
    nu = nu*mu_gyro


    # Ordered YBO component 
    term1 = f_F * (2/3) * np.exp(-0.5 * (sigma * t)**2) * np.cos(2 * np.pi * nu * t + phi_rad)
    
    # Ordered Tail exponential decay
    term2 = f_F * (1/3) * np.exp(-(lam_tail * t)**beta_tail)
    
    # Disordered YBO paramagnetic component
    term3 = (1 - f_F) * np.exp(-(lam_para * t)**beta_para)
    
    # Silver (Ag) component
    term4 = np.exp(-(lam_Ag * t)**beta_Ag)
    
    # Full asymmetry function
    #A = A_T * (1 - Ag_F) * (term1 + term2 + term3) + A_T * Ag_F * term4

    A1= A_T * (1 - Ag_F) * (term1) #K-T gaussian damped cosine
    A2= A_T * (1 - Ag_F) * (term2) #Ordered Tail term
    A3= A_T * (1 - Ag_F) * (term3) #Disordered paramagnetic
    A4= A_T * Ag_F * term4 #Silver component
    A5=A1+A2+A3+A4

    plt.plot(times, A1, label='K-T gaussian damped cosine', color='r')
    plt.plot(times, A2, label='Ordered Tail term', color='gold')
    plt.plot(times, A3, label='Disordered paramagnetic', color='green')
    plt.plot(times, A4, label='Silver component', color='silver')

    plt.plot(times, A5, label='CheckTheyAdd', color='magenta')


    #plt.ylim(0,0.25)
    #plt.axhline(0.2392,color = 'r', label='Original Asy_tot')
    plt.xlim(0,1)
    plt.title(f'YBO Musr fit parameters for run {run_no}, {Temp} K')
    plt.plot(times, A, label='Full Asymmetry', color='b')
    plt.legend()
    plt.show()

#Plot_YBO_fit_components(2460, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2465, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2466, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2467, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2468, 'beta_fixed_post_lock_25_009.txt')
#Plot_YBO_fit_components(2460, 'beta1_July_08_002.txt')
#Plot_YBO_fit_components(2467, 'beta1_July_08_002.txt')
#Plot_YBO_fit_components(2468, 'beta1_July_08_002.txt')
