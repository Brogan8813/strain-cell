# %%
import pandas
import matplotlib.pyplot as plt
import numpy as np

#To get nice font:
from matplotlib import font_manager as fm
a= 'C:\\Windows\\Fonts\\times.TTF'
fprop = fm.FontProperties(fname=a)
plt.rcParams['font.family'] = fprop.get_name()
#To get nice font:

FILEPATH ="C:/Users/thoma/Documents/Physics_Work/Python Scripts/strain-cell/PPMS_Data_and_Plotting/Data/YbBO3/alpha_vs_temp_08-05-25.csv"
df = pandas.read_csv(FILEPATH, sep=",", encoding='unicode_escape')

x1 = df.loc[:,'Temperature (K)']
y1 = df.loc[:,'Alpha']
y1err=df['Alpha_err']

x2 = df.loc[:,'Temperature (K)']
y2 = df.loc[:,'A_0']
y2err=df['A_0_err']



''''''
plt.scatter(x1, y1, s=50, 
                #c='r', 
                facecolors='b', edgecolors= 'b', label = 'Alpha')
'''                
plt.errorbar(x1, y1, yerr=y1err,capsize=4,                    # little cap on the error bar
    ecolor='gray',                # color of error bars
    elinewidth=1.2,
    markerfacecolor='blue')'''

#plt.plot(x1, y1, c='b', linewidth=0.8)

'''
plt.scatter(x2, y2, marker='x', s=50, 
                #c='r', 
                facecolors='r', edgecolors= 'r', label = 'A_0')
''''''
plt.errorbar(x2, y2, yerr=y2err,capsize=4,                    # little cap on the error bar
    ecolor='gray',                # color of error bars
    elinewidth=1.2,
    markerfacecolor='blue')'''

#plt.plot(x2, y2, c='r', linewidth=0.8)



#plt.xlim(0,10.5)
plt.title('YbBO3 Alpha and A_0 vs Temperature',fontsize=20,weight='bold')
plt.xlabel('Temperature (K)',fontsize=20,weight='bold')
plt.ylabel('Alpha, A_0',fontsize=20,weight='bold')
plt.grid('both')
plt.legend()
plt.show()
