# %%
import numpy as np 
np.logspace(0, 2, num=10)*3
# Out:
# array([  3.        ,   5.00430161,   8.34767821,  13.9247665 ,
#         23.22791048,  38.74648995,  64.6330407 , 107.81440991,
#        179.8452751 , 300.        ])
